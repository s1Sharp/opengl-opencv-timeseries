# %% [markdown]
# # Prepare Custom Dataset (10 Monkey Species)
# ### URL: https://www.kaggle.com/datasets/slothkong/10-monkey-species/download?datasetVersionNumber=2

# %%
# !pip install -q opendatasets

import opendatasets as od
import pandas as pd

# {"username":"tsarkovmaksim","key":"74ef4b514ef55236e65eaa869060d3ac"}
od.download('https://www.kaggle.com/datasets/slothkong/10-monkey-species/download?datasetVersionNumber=2') # insert ypu kaggle  username and key
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: tsarkovmaksim
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 547M/547M [00:19<00:00, 29.6MB/s]

# %%
ls -al 10-monkey-species/
# Out:
# total 20
# drwxr-xr-x 4 root root 4096 Dec  8 11:31 ./
# drwxr-xr-x 1 root root 4096 Dec  8 11:30 ../
# -rw-r--r-- 1 root root  928 Dec  8 11:31 monkey_labels.txt
# drwxr-xr-x 3 root root 4096 Dec  8 11:31 training/
# drwxr-xr-x 3 root root 4096 Dec  8 11:31 validation/

# %%
ls -al 10-monkey-species/validation/validation
# Out:
# total 48
# drwxr-xr-x 12 root root 4096 Dec  8 11:31 ./
# drwxr-xr-x  3 root root 4096 Dec  8 11:31 ../
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n0/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n1/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n2/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n3/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n4/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n5/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n6/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n7/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n8/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n9/

# %%
ls -al 10-monkey-species/training/training
# Out:
# total 48
# drwxr-xr-x 12 root root 4096 Dec  8 11:31 ./
# drwxr-xr-x  3 root root 4096 Dec  8 11:31 ../
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n0/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n1/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n2/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n3/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n4/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n5/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n6/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n7/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n8/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 n9/

# %%
cat ./10-monkey-species/monkey_labels.txt
# Out:
# Label,  Latin Name           , Common Name                   , Train Images , Validation Images
# n0   , alouatta_palliata	 , mantled_howler                , 131          , 26
# n1   , erythrocebus_patas	 , patas_monkey                  , 139          , 28
# n2   , cacajao_calvus	     , bald_uakari                   , 137          , 27
# n3   , macaca_fuscata	     , japanese_macaque              , 152          , 30
# n4   , cebuella_pygmea	     , pygmy_marmoset                , 131          , 26
# n5   , cebus_capucinus	     , white_headed_capuchin         , 141          , 28
# n6   , mico_argentatus	     , silvery_marmoset              , 132          , 26
# n7   , saimiri_sciureus	     , common_squirrel_monkey        , 142          , 28
# n8   , aotus_nigriceps	     , black_headed_night_monkey     , 133          , 27
# n9   , trachypithecus_johnii , nilgiri_langur                , 132          , 26

# %%
# !find 10-monkey-species/ -type d -name "n0" -exec sh -c 'mv "$0" "${0%/*}/alouatta_palliata/"' {} \;
# !find 10-monkey-species/ -type d -name "n1" -exec sh -c 'mv "$0" "${0%/*}/erythrocebus_patas/"' {} \;
# !find 10-monkey-species/ -type d -name "n2" -exec sh -c 'mv "$0" "${0%/*}/cacajao_calvus/"' {} \;
# !find 10-monkey-species/ -type d -name "n3" -exec sh -c 'mv "$0" "${0%/*}/macaca_fuscata/"' {} \;
# !find 10-monkey-species/ -type d -name "n4" -exec sh -c 'mv "$0" "${0%/*}/cebuella_pygmea/"' {} \;
# !find 10-monkey-species/ -type d -name "n5" -exec sh -c 'mv "$0" "${0%/*}/cebus_capucinus/"' {} \;
# !find 10-monkey-species/ -type d -name "n6" -exec sh -c 'mv "$0" "${0%/*}/mico_argentatus/"' {} \;
# !find 10-monkey-species/ -type d -name "n7" -exec sh -c 'mv "$0" "${0%/*}/saimiri_sciureus/"' {} \;
# !find 10-monkey-species/ -type d -name "n8" -exec sh -c 'mv "$0" "${0%/*}/aotus_nigriceps/"' {} \;
# !find 10-monkey-species/ -type d -name "n9" -exec sh -c 'mv "$0" "${0%/*}/trachypithecus_johnii/"' {} \;
# Out:
# find: ‘10-monkey-species/validation/validation/n0’: No such file or directory
# find: ‘10-monkey-species/training/training/n0’: No such file or directory
# find: ‘10-monkey-species/validation/validation/n1’: No such file or directory
# find: ‘10-monkey-species/training/training/n1’: No such file or directory
# find: ‘10-monkey-species/validation/validation/n2’: No such file or directory
# find: ‘10-monkey-species/training/training/n2’: No such file or directory
# find: ‘10-monkey-species/validation/validation/n3’: No such file or directory
# find: ‘10-monkey-species/training/training/n3’: No such file or directory
# find: ‘10-monkey-species/validation/validation/n4’: No such file or directory
# find: ‘10-monkey-species/training/training/n4’: No such file or directory
# find: ‘10-monkey-species/validation/validation/n5’: No such file or directory
# find: ‘10-monkey-species/training/training/n5’: No such file or directory
# ...

# %%
ls -al 10-monkey-species/validation/validation
# Out:
# total 48
# drwxr-xr-x 12 root root 4096 Dec  8 11:31 ./
# drwxr-xr-x  3 root root 4096 Dec  8 11:31 ../
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 alouatta_palliata/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 aotus_nigriceps/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 cacajao_calvus/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 cebuella_pygmea/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 cebus_capucinus/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 erythrocebus_patas/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 macaca_fuscata/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 mico_argentatus/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 saimiri_sciureus/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 trachypithecus_johnii/

# %%
ls -al 10-monkey-species/training/training
# Out:
# total 48
# drwxr-xr-x 12 root root 4096 Dec  8 11:31 ./
# drwxr-xr-x  3 root root 4096 Dec  8 11:31 ../
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 alouatta_palliata/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 aotus_nigriceps/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 cacajao_calvus/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 cebuella_pygmea/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 cebus_capucinus/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 erythrocebus_patas/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 macaca_fuscata/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 mico_argentatus/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 saimiri_sciureus/
# drwxr-xr-x  2 root root 4096 Dec  8 11:31 trachypithecus_johnii/

# %%
import torchvision
import numpy as np
import torch
import glob
import os

train_path = glob.glob('/content/10-monkey-species/training/training/**/*.jpg')
test_path = glob.glob('/content/10-monkey-species/validation/validation/**/*.jpg')
target_names = np.sort(os.listdir('/content/10-monkey-species/training/training'))
# [
#     "alouatta_palliata",
#     "erythrocebus_patas",
#     "cacajao_calvus",
#     "macaca_fuscata",
#     "cebuella_pygmea",
#     "cebus_capucinus",
#     "mico_argentatus",
#     "saimiri_sciureus",
#     "aotus_nigriceps",
#     "trachypithecus_johnii",
# ]
print(target_names)
# Out:
# ['alouatta_palliata' 'aotus_nigriceps' 'cacajao_calvus' 'cebuella_pygmea'
#  'cebus_capucinus' 'erythrocebus_patas' 'macaca_fuscata' 'mico_argentatus'
#  'saimiri_sciureus' 'trachypithecus_johnii']

# %%
import random
# Вариант 1
# dataset_train = []
# for path in imgs_train:
#     for i, target in enumerate(targets):
#         if target in path:
#             dataset_train.append((path, i))

# Вариант 2
train_dataset_path = [(path, np.argmax(list(map(lambda target: target in path, target_names)))) for path in train_path]

test_dataset_path = [(path, np.argmax(list(map(lambda target: target in path, target_names)))) for path in test_path]
random.sample(train_dataset_path, 10)
# Out:
# [('/content/10-monkey-species/training/training/trachypithecus_johnii/n9056.jpg',
#   9),
#  ('/content/10-monkey-species/training/training/mico_argentatus/n6023.jpg', 7),
#  ('/content/10-monkey-species/training/training/cebus_capucinus/n5149.jpg', 4),
#  ('/content/10-monkey-species/training/training/trachypithecus_johnii/n9133.jpg',
#   9),
#  ('/content/10-monkey-species/training/training/trachypithecus_johnii/n9132.jpg',
#   9),
#  ('/content/10-monkey-species/training/training/cebuella_pygmea/n41564.jpg',
#   3),
#  ('/content/10-monkey-species/training/training/trachypithecus_johnii/n9116.jpg',
#   9),
#  ('/content/10-monkey-species/training/training/alouatta_palliata/n0153.jpg',
#   0),
#  ('/content/10-monkey-species/training/training/alouatta_palliata/n0150.jpg',
#   0),
#  ('/content/10-monkey-species/training/training/alouatta_palliata/n0132.jpg',
#   0)]

# %%
from torch.utils.data import Dataset
import cv2

class WildCatsDataset(Dataset):
    def __init__(self, dataset, transforms):
        self.dataset = dataset
        self.transforms = transforms

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img = cv2.imread(self.dataset[idx][0])
        # Загрузка изображения в градациях серого
        # img = cv2.imread(self.dataset[idx][0], cv2.IMREAD_GRAYSCALE)
        img = self.transforms(img)
        target = self.dataset[idx][1]
        return img, target

# %%
img_size = (128, 128, 3)
transforms = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Resize((img_size[0], img_size[1])),
])

train_dataset = WildCatsDataset(train_dataset_path, transforms)
test_dataset = WildCatsDataset(test_dataset_path, transforms)

train_dataset[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# (tensor([[[0.8390, 0.4163, 0.3134,  ..., 0.9657, 0.3544, 0.1366],
#           [0.4106, 0.2843, 0.2430,  ..., 0.9531, 0.7874, 0.1353],
#           [0.3111, 0.2347, 0.1525,  ..., 0.8855, 0.8470, 0.1422],
#           ...,
# ...

# %%
import matplotlib.pyplot as plt
num_img = 0
test_img = np.array(train_dataset[num_img][0]).transpose(1, 2, 0)[..., ::-1]
print(f'Class id: {train_dataset[num_img][1]} Class name: {target_names[train_dataset[num_img][1]]}')
plt.imshow(test_img)
# Out:
# Class id: 4 Class name: cebus_capucinus

# %% [markdown]
# # DataLoader

# %%
len(train_dataset)
# Out:
# 1096

# %%
batch_size = 32
train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
for images, targets in train_loader:
    print(images.shape, targets.shape)
    break
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# torch.Size([32, 3, 128, 128]) torch.Size([32])

# %% [markdown]
# # Models

# %%
import torch.nn as nn
import torch.nn.functional as F

# Модель полносвязной сети
class NN(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(NN, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)

    def forward(self, X):
        X = X.flatten(start_dim=1)
        out = F.relu(self.fc1(X))
        out = F.relu(self.fc2(out))
        out = self.fc3(out)
        return out

# Простейшая модель сверточных нейронных сетей
class CNN(nn.Module):
    def __init__(self, img_size):
        super(CNN, self).__init__()

        # Сверточные слои
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)

        # Полносвязные слои
        self.fc1 = nn.Linear(img_size[0]//4*img_size[1]//4 * 32, 256)
        self.fc2 = nn.Linear(256, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


class ImprovedCNN(nn.Module):
    def __init__(self, img_size):
        super(ImprovedCNN, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(16)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(32)

        self.fc1 = nn.Linear(img_size[0]//4 * img_size[1]//4 * 32, 256)
        self.fc2 = nn.Linear(256, 10)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.max_pool2d(x, 2)
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')
# Out:
# Device: cuda

# %%
import time
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# Функция для обучения модели
def train_model(model, train_loader, criterion, optimizer, device):
    model.train()
    total_loss = 0.0
    for images, targets in train_loader:
        images, targets = images.to(device), targets.to(device)
        optimizer.zero_grad()
        pred = model(images)
        loss = criterion(pred, targets)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(train_loader)

# Функция для валидации модели
def validate_model(model, val_loader, criterion, device):
    model.eval()
    total_loss = 0.0
    with torch.no_grad():
        for images, targets in val_loader:
            images, targets = images.to(device), targets.to(device)
            pred = model(images)
            loss = criterion(pred, targets)
            total_loss += loss.item()
    return total_loss / len(val_loader)

# Гиперпараметры для валидации
learning_rates = [0.001, 0.01, 0.1]
batch_sizes = [32, 64, 128]
criterions = [nn.CrossEntropyLoss, nn.NLLLoss]
num_epochs = 10

for criteria in criterions:
    for lr in learning_rates:
        for batch_size in batch_sizes:
            # Инициализация модели, критерия и оптимизатора для каждой комбинации гиперпараметров
            model = ImprovedCNN(img_size).to(device)
            criterion = criteria()
            optimizer = torch.optim.Adam(model.parameters(), lr=lr)
            train_loader_ = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
            val_loader_ = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

            # Обучение модели
            for epoch in range(num_epochs):
                train_loss = train_model(model, train_loader_, criterion, optimizer, device)
                val_loss = validate_model(model, val_loader_, criterion, device)

                print(f'Epoch {epoch+1}/{num_epochs}, LR: {lr}, Batch Size: {batch_size}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Criterion: {criterion}')

# Как только найдены оптимальные гиперпараметры, вы можете использовать их для обучения
# вашей модели на всем наборе данных и оценки на тестовом наборе.
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 1/10, LR: 0.001, Batch Size: 32, Train Loss: 5.1627, Val Loss: 2.2115, Criterion: CrossEntropyLoss()
# Epoch 2/10, LR: 0.001, Batch Size: 32, Train Loss: 2.1021, Val Loss: 2.1417, Criterion: CrossEntropyLoss()
# ...

# %%
# Гиперпараметры для валидации
learning_rates = [0.001]
batch_sizes = [32, 128]
criterions = [nn.NLLLoss]
num_epochs = 10

for criteria in criterions:
    for lr in learning_rates:
        for batch_size in batch_sizes:
            # Инициализация модели, критерия и оптимизатора для каждой комбинации гиперпараметров
            model = ImprovedCNN(img_size).to(device)
            criterion = criteria()
            optimizer = torch.optim.Adam(model.parameters(), lr=lr)
            train_loader_ = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
            val_loader_ = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

            # Обучение модели
            for epoch in range(num_epochs):
                train_loss = train_model(model, train_loader_, criterion, optimizer, device)
                val_loss = validate_model(model, val_loader_, criterion, device)

                print(f'Epoch {epoch+1}/{num_epochs}, LR: {lr}, Batch Size: {batch_size}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Criterion: {criterion}')
# Out:
# Epoch 1/10, LR: 0.001, Batch Size: 32, Train Loss: -1336.0127, Val Loss: -849.6879, Criterion: NLLLoss()
# Epoch 2/10, LR: 0.001, Batch Size: 32, Train Loss: -12964.9657, Val Loss: -20663.6066, Criterion: NLLLoss()
# Epoch 3/10, LR: 0.001, Batch Size: 32, Train Loss: -48838.4584, Val Loss: -79776.1658, Criterion: NLLLoss()
# Epoch 4/10, LR: 0.001, Batch Size: 32, Train Loss: -125389.7554, Val Loss: -176393.4566, Criterion: NLLLoss()
# Epoch 5/10, LR: 0.001, Batch Size: 32, Train Loss: -252372.1746, Val Loss: -355888.6285, Criterion: NLLLoss()
# Epoch 6/10, LR: 0.001, Batch Size: 32, Train Loss: -450669.6562, Val Loss: -527911.5208, Criterion: NLLLoss()
# Epoch 7/10, LR: 0.001, Batch Size: 32, Train Loss: -729526.0286, Val Loss: -861175.8194, Criterion: NLLLoss()
# Epoch 8/10, LR: 0.001, Batch Size: 32, Train Loss: -1113754.9643, Val Loss: -1486070.0556, Criterion: NLLLoss()
# ...

# %%
batch_size = 32
train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
import time
learning_rate = 0.001
num_epochs = 50 # 101
input_dim = np.prod(img_size)
hidden_dim = 256
output_dim = 10

# MLP
# model = NN(input_dim, hidden_dim, output_dim).to(device)

# CNN
# model = CNN(img_size).to(device)

# ImprovedCNN
model = ImprovedCNN(img_size).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

loss_train_by_epoch = []
st = time.time()
for epoch in range(num_epochs):
    loss_train = []
    for i, (images, targets) in enumerate(train_loader):
        images, targets = images.to(device), targets.to(device)
        optimizer.zero_grad()
        pred = model(images)
        loss = criterion(pred, targets)
        loss.backward()
        optimizer.step()
        loss_train.append(loss.item())
    loss_train_by_epoch.append(loss_train)
    if epoch%2==0:
        print(f'Epoch: {epoch} | Error: {np.mean(loss_train)}')

print(f'Elapsed Time: {time.time()-st} s')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch: 0 | Error: 5.2632867676871165
# Epoch: 2 | Error: 1.8525136096136912
# Epoch: 4 | Error: 1.6298300334385463
# Epoch: 6 | Error: 1.4368239845548356
# Epoch: 8 | Error: 1.316216448375157
# Epoch: 10 | Error: 1.2393713865961347
# Epoch: 12 | Error: 1.1114788600376675
# ...

# %%
loss_train_by_epoch = np.array(loss_train_by_epoch)

# %%
# Извлечение данных
epochs = range(1, len(loss_train_by_epoch) + 1)
loss = [np.mean(l) for l in loss_train_by_epoch]

# Построение графика
plt.plot(epochs, loss, marker='o', linestyle='-')
plt.title('Зависимость ошибки обучения от номера эпохи')
plt.xlabel('Номер эпохи')
plt.ylabel('Ошибка обучения')
plt.grid(True)
plt.show()

# %%
def get_accuracy(data_loader, model):
    acc = 0
    for i, (images, targets) in enumerate(data_loader):
        images, targets = images.to(device), targets.to(device)
        pred = model(images)
        result = torch.argmax(pred, dim=1)
        acc += torch.sum(result==targets).item()
    return acc

acc_train = get_accuracy(train_loader, model)
print(f'Accuracy Train: {np.round(acc_train/len(train_dataset)*100,2)}%')

acc_test = get_accuracy(test_loader, model)
print(f'Accuracy Test: {np.round(acc_test/len(test_dataset)*100,2)}%')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Accuracy Train: 79.01%
# Accuracy Test: 44.49%

# %%
# Сохранение модели с обученными весами в файл
# torch.save(model, 'model_weights.pth')

# Загрузка модели
# model_load = torch.load('model_weights.pth')

# %% [markdown]
# # Predict and visualize one image

# %%
import matplotlib.pyplot as plt
num_img = 30

image, target = test_dataset[num_img][0].to(device), test_dataset[num_img][0].to(device)
output = model(image[None,...])
pred = torch.argmax(output)
probability = torch.max(F.softmax(model(image[None,...]), dim=1))

plt.title(f'Target: {target_names[test_dataset[num_img][1]]} | '
          f'Prediction: {target_names[pred]} | \n'
          f'Probability: {torch.round(probability*100)}%')
test_img = np.array(test_dataset[num_img][0]).transpose(1, 2, 0)[..., ::-1]
plt.imshow(test_img)

# %% [markdown]
# # ДЗ

# %% [markdown]
# ## Обучить модель на собственном наборе данных:
# 1) выберите набор данных для решения задачи классификации;
# 2) используя PyTorch, создайте модель нейронной сети для обучения на выбранном наборе данных;
# 3) обучите модель, оцените ее точность на обучающей и тестовой выборках;
# 4) постройте графики зависимости ошибки от кол-ва эпох;
# 5) подберите параметры модели, если это необходимо, чтобы улучшить ее результаты.
